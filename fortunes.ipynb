# %%
import pandas as pd
import datetime as dt

# %%
df = pd.read_csv('star_sign.csv', parse_dates=['date_from', 'date_to'], date_format='%d/%m')
df
# Out:
#       star_sign  date_from    date_to  number
# 0         Aries 1900-03-21 1900-04-19       1
# 1        Taurus 1900-04-20 1900-05-20       2
# 2        Gemini 1900-05-21 1900-06-20       3
# 3        Cancer 1900-06-21 1900-07-22       4
# 4           Leo 1900-07-23 1900-08-22       5
# 5         Virgo 1900-08-23 1900-09-22       6
# 6         Libra 1900-09-23 1900-10-22       7
# 7       Scorpio 1900-10-23 1900-11-21       8
# 8   Sagittarius 1900-11-22 1900-12-21       9
# 9     Capricorn 1900-12-21 1900-01-20      10
# 10     Aquarius 1900-01-21 1900-02-18      11
# 11       Pisces 1900-02-19 1900-03-20      12

# %%
#df['date_from'] = df['date_from'].dt.strftime('%d/%m')
#df['date_to'] = df['date_to'].dt.strftime('%d/%m')
#change_to_datetime = {'date_from': datetime, 'date_to': datetime}
df[['date_from', 'date_to']] = df[['date_from', 'date_to']].apply(pd.to_datetime, format='%d/%m')
df
# Out:
#       star_sign  date_from    date_to  number
# 0         Aries 1900-03-21 1900-04-19       1
# 1        Taurus 1900-04-20 1900-05-20       2
# 2        Gemini 1900-05-21 1900-06-20       3
# 3        Cancer 1900-06-21 1900-07-22       4
# 4           Leo 1900-07-23 1900-08-22       5
# 5         Virgo 1900-08-23 1900-09-22       6
# 6         Libra 1900-09-23 1900-10-22       7
# 7       Scorpio 1900-10-23 1900-11-21       8
# 8   Sagittarius 1900-11-22 1900-12-21       9
# 9     Capricorn 1900-12-21 1900-01-20      10
# 10     Aquarius 1900-01-21 1900-02-18      11
# 11       Pisces 1900-02-19 1900-03-20      12

# %%
#filtered_df = df['date_from'] > '18/08'
filtered_df = df.loc[(df['date_to'] >= '18-08')]
filtered_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Sigma/sigma-prework/capstone/venv/lib/python3.11/site-packages/pandas/_libs/tslibs/parsing.pyx:679, in pandas._libs.tslibs.parsing.dateutil_parse()
#
# ValueError: month must be in 1..12
#
# The above exception was the direct cause of the following exception:
#
# DateParseError                            Traceback (most recent call last)
# File ~/Sigma/sigma-prework/capstone/venv/lib/python3.11/site-packages/pandas/core/arrays/datetimelike.py:557, in DatetimeLikeArrayMixin._validate_comparison_value(self, other)
#     555 try:
#     556     # GH#18435 strings get a pass from tzawareness compat
# --> 557     other = self._scalar_from_string(other)
#     558 except (ValueError, IncompatibleFrequency):
#     559     # failed to parse as Timestamp/Timedelta/Period
#
# ...
